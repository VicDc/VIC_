# %% [markdown]
# <a href="https://colab.research.google.com/github/VicDc/VIC_/blob/OPIT/VDC_A2_c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install PyPDF2
! pip install fpdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=470f4f1d73fea50e84fb8d634756e2dbdd0fc75c17399c8c383b622c2271a959
#   Stored in directory: /root/.cache/pip/wheels/65/4f/66/bbda9866da446a72e206d6484cd97381cbc7859a7068541c36
# Successfully built fpdf
# ...

# %% [markdown]
# # **(ENG)Bias and Fairness Analysis:**
#
#
#
# *   The text contains 3 references to conspiratorial themes.
# *   The text refers to institutions 11 times, potentially indicating bias.
# *   The text includes negative terminology 3 times.
#
#
# Overall Fairness Analysis:
#
# The report portrays health officials and governments in a decidedly negative and conspiratorial light, falsely attributing malicious intent (such as microchipping or profiteering) without evidence. It also denies the scientifically supported effectiveness of the vaccine. Therefore, the text is not fair or balanced. It spreads unfounded fear, distrust, and misinformation

# %%
# 1. Notebook Imports
import os
import PyPDF2

from fpdf import FPDF

# %%
###########################################################
# 2. In this case I used the trascription of a youtube interview by BarbascuraX. Barbascura X is an Italian science communicator, During the Covid pandemic,
#he interviewed NoVax protesters, demonstrating the inaccuracy and falsehoods of the NoVax claims.
#
#https://youtu.be/N9OMSELIcEg?si=oSzOEmR3U7qnNG4W
#
#IMPORTANT:
#The following transcript is partial DISINFORMATION and demonstrates that spreading information without the knowledge to understand it can create more harm.
###########################################################
fake_report_text = """
È tutto complotto criminale dall'ordine mondiale.
Noi siamo contrari al 5G. Va assolutamente fermato, fermato, fermato, fermato.
Ciao, sono Mariolone Bubarello, giornalista scientifico scettico e benvenuti alla piazza dei negazionisti del Covid. Sì, ma prima fatemi dire una cosa. La manifestazione a cui mi trovavo era la marcia della liberazione.
Liberazione? Liberazione da che? Ma dalla dittatura sanitaria, ovvio.
Ah,
questa dittatura sanitaria.
Un evento avvenuto proprio durante il periodo di innalzamento. di casi di Covid in tutto il mondo. Perché d'altro canto qual è il miglior periodo per incontrarsi tutti quanti in piazza? Abbracciarci. Secondo me stiamo meglio se stiamo vicini uno all'altro piuttosto che lontani.
Ringrazio
stare lontani uno dall'altro non fa bene alla salute e noi dobbiamo tenerci in salo per questa occasione.
D'altronde sono nato troppo tardi per vedermi un concerto dal vivo Nirvana e troppo presto per trasferirmi su Marte. Però in compenso sono nato nel periodo giusto per partecipare alla lotta contro la dittatura sanitaria perché insomma Eh, e ci tengo a sottolinearlo. E dal palco hanno detto diverse volte che loro non erano negazionisti.
Il discorso negazionista è anche abbastanza offensivo.
Chiamali come ti pare, ma negazionisti proprio no. Eh, no.
Muore nessuno di questa malattia perché è una c**** di influenza.
Un fantavirus
non c'è
assolutamente nessun negazionista. Non credo ai decessi, non credo praticamente a un sacco di cose. Perché loro non negavano mica l'esistenza del virus. Scusa,
non c'amo niente nessuno. È tutta una barzelletta sta s********.
Dura perché il Covid non esiste.
Ok, qualcuno lo negava, però non Tutti, non tutti, molti negavano soltanto l'esistenza delle vittime del virus, eh, oppure l'inutilità delle misure di sicurezza, l'inutilità della mascherina. È diverso, è diverso. Certo, tutto si può dire tranne che gli manchi la coerenza.
Io non ho visto morire un cane, un gatto. Io c'ho due gatti a casa.
Eh,
stanno benissimo.
In che senso?
Guarda che cosa hai vinto.
No,
ma perché tutti questi premi Nobel non erano lì attaccati al telefono nell'attesa di scoprire se avessero vinto Meno alla fine erano stati candidati, no? Erano in Lizza, no? Perché non lo sapevano, non lo sa nessuno. Nessuno sa niente. Ovviamente ci sono dei modi con cui la commissione può candidare delle persone, ovviamente, altrimenti come farebbero, però nessuno al di fuori di loro sa niente dei nomi, chi cosa succede. Non non sappiamo niente.
Le nomination per i Nobel si sanno, però con 50 anni di ritardo. Esiste l'archivio delle nomination sul sito dell'Accademia dei Nobel e a suo modo è super interessante perché scopri cose tipo Robert Cock, uno dei fondatori della microbiologia, quello che ha scoperto che la tubercolosi è causata da un batterio, ha vinto il Nobel nel 1905 dopo 60 nomination, praticamente come Leo di Caprio con l'Oscar. E questo proprio per evitare che qualcuno vada in giro a millantare di essere stato un candidato ai premi Nobel. Ma poi uno che scrive sul curriculum candidato premio Ma che davvero? Ehi, lo sai che sono stato candidato alla finale di X Factor? Wow! Davvero? Aspe, ma in che senso? Penso che nel 2010 mi sono presentato ai provini. Ah! E e che t' hanno detto? Le faremo sapere. Ah, e quindi sei un candidato
candidato finalista. Ok. Io comunque sto procedendo a candidare il mio amico. Non importa se vince o meno, tanto io nel curriculum glielo metto comunque che io gli ho candidato al primo Nobel, quindi onesto. Avanti, candidiamoci tutti, tutti i candidati primi
se uno va a vedere la mortalità complessiva in Italia nei primi mesi, quest'anno Ci sono decine di migliaia di morti in meno.
Anche questa è una bufala e anche dolorosa che ha girato molto. Il numero a sinistra è vero, quello a destra totalmente inventato, dato che l'Istat non ha ancora prodotto quel dato. Se però guardiamo il dato parziale per alcune regioni, le linee blu sono le morti dell'anno scorso, quelle arancioni sono di quest'anno. Potete vedere da voi che purtroppo sono morte quasi il 50% in più delle persone. E questo nonostante il lockdown e tutte le precauzioni che stiamo prendendo o quantomeno proviamo a prendere in tutto ciò. Comunque vi faccio notare quanto sia triste il fatto che eh si giochi sui numeri come se quei numeri non fossero delle persone. Molto molto triste.
Dove sono i morti?
Dove sono i morti?
E occhio, questa immagine ha girato un sacco su Facebook come post, quindi per qualcuno un post su Facebook è una dichiarazione ufficiale indubitabile. Immagino che è per questa gente che esistono ancora le pubblicità sull'allungamento del pene.
La scienza non è pensiero unico, sennò diventa dogma.
No, ma sono d'accordo. Però lei cosa mi direbbe se io venissi da lei e le dicessi che secondo me la velocità della luce è di tre al secondo.
Perché? Spiegami. Non capisco il tuo esempio.
A questo punto mi si avvicina un ragazzo chiedendomi di intervistare anche altre persone, lasciandomi intendere che secondo lui io stia intervistando le persone sbagliate. Allora gli chiedo se vuol farsi intervistare e mi dice "No". Allora mi metto a parlare con un altro ragazzo. Anche lui non vuole essere intervistato, ma mi presenta una sua amica che ha fatto un documentario contro i vaccini. Mi sono fatto dei nuovi amici. In tutto ciò vi confesso che qualcuno m'ha fatto pure rimanere male, cioè mi sono avvicinato a ste due ragazze, le ho chiesto un'intervista, allora mi fanno "No, che schifo, barba scura, è un debunker." Un debunker. The bunker. Era a me.
Ok. Allora, le cose più banali in realtà sono le più difficili. C'è un esempio che gira tra colleghi di un bambino che abbia chiesto una volta "Ma perché esiste la gravità?" Cioè, come faccio a dire che esiste la gravità? Eh, perché il sasso cade. E perché il sasso cade? Perché esiste la gravità. E quindi in realtà le cose più semplici sono le cose più difficili da dimostrare.
E la cosa che più mi fa male è che alcuni di loro ripetevano le stesse identiche parole a pappagallo.
Sviluppa la tempesta di citochine
che crea una tempesta citochimica. Scusate, magari ho sbagliato, non sono uno scienziato. intere frasi, termini spesso manco capiti, però ho capito che ho visto pubblicare sempre dai soliti canali, quelli che stanno cavalcando la crisi in ogni modo possibile immaginabile, continuando a pubblicare disinformazione su disinformazione soltanto per fare qualche click. La gente ha comprensibilmente paura e se trova il titolone allarmistico, prima ancora di verificare se sia vero o meno, prima ancora di farsi venire il dubbio, lo condivide alla chat di famiglia. Chat di famiglia dove potrebbe esserci una persona come me, a cui viene un ictus in questi casi, che io voglio ammazzare tutti quanti. Un ciao a Bill Gates che ci segue sempre e noi ci vediamo nella sezione commenti che questa volta si prevede. Bella crocca Cantella. Un salutazzo a tutti da Tarallo e da Barba Scura. Sfera e barba in
Ehi, anni fa, bello mio, mi era venuta un'idea. Pensavo che il sole fosse una lampada de Gea. Ora invece quando prendo il micro Bach ti entro dentro come B con il micro G. Quale il 5G? Dimmi dove corre che il 4G A me già dura quattro giorni. Sono sfera e barba, il tuo nuovo Dio. La mia barba non è fatta, sono fatto io. La terra non è piatta, la terra è la mia piazza. L'unica cosa piatta è la tua ragazza. Ho capito adesso perché io ho il 5G. Non ti si drizza l'antenna mentre lui sei. Fate teoria a caso. Io teoria del caos. Sono fresco come fare il rap sopra la house. Vi saluto complottisti. Allora, ciao. La mia laurea non è fake, è fake il vostro account. Uh. Perfetto. Vi saluto complottisti. Allora, ciao. La mia laurea non è fake, è fake soltanto il vostro account.
Oh!
"""

# %%
################################################################
# 3. Save the Disinformation Report to a PDF File
# The PDF will be named: BarbascuraX_NoVAX.pdf
################################################################

pdf_filename = "BarbascuraX_NoVAX.pdf"

# Create a simple PDF using FPDF
pdf = FPDF()
pdf.add_page()

# Set font
pdf.set_font("Arial", size=12)

# Break the report text into lines
lines = fake_report_text.split("\n")

for line in lines:
    pdf.multi_cell(0, 5, line)
    pdf.ln()

# Save the PDF
pdf.output(pdf_filename)

print(f"Fake report PDF generated: {pdf_filename}")
# Out:
# Fake report PDF generated: BarbascuraX_NoVAX.pdf

# %%
############################################################
# 4. Read the PDF and Extract the Text for Analysis
############################################################
extracted_text = ""

with open(pdf_filename, 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    num_pages = len(reader.pages)
    for page_num in range(num_pages):
        page = reader.pages[page_num]
        extracted_text += page.extract_text() + "\n\n"

print("Extracted text from PDF:")
print(extracted_text)
# Out:
# Extracted text from PDF:
# È tutto complotto criminale dall'ordine mondiale.
# Noi siamo contrari al 5G. Va assolutamente fermato, fermato, fermato, fermato.
# Ciao, sono Mariolone Bubarello, giornalista scientifico scettico e benvenuti alla piazza dei
# negazionisti del Covid. Sì, ma prima fatemi dire una cosa. La manifestazione a cui mi trovavo era la
# marcia della liberazione.
# Liberazione? Liberazione da che? Ma dalla dittatura sanitaria, ovvio.
# Ah,
# questa dittatura sanitaria.
# Un evento avvenuto proprio durante il periodo di innalzamento. di casi di Covid in tutto il mondo.
# Perché d'altro canto qual è il miglior periodo per incontrarsi tutti quanti in piazza? Abbracciarci.
# Secondo me stiamo meglio se stiamo vicini uno all'altro piuttosto che lontani.
# Ringrazio
# stare lontani uno dall'altro non fa bene alla salute e noi dobbiamo tenerci in salo per questa
# occasione.
# D'altronde sono nato troppo tardi per vedermi un concerto dal vivo Nirvana e troppo presto per
# ...

# %%
###################################################################
# 5. Analyze the Bias and Fairness of the Content
#
# Since this content is disinformation, we will look for:
#  - Potential sources of bias against specific groups or institutions
#  - Misrepresentation or unfair portrayal of facts and data
#  - Overall fairness, or lack thereof, in the portrayal of COVID-19 vaccination
###################################################################

def analyze_bias_and_fairness(text):
    """
    A simple heuristic analysis of how the text might contain bias or unfair claims.
    This is rudimentary and for demonstration only.
    """
    analysis_report = ""

    # Check for certain keywords that might indicate conspiracy or bias
    # (Purely illustrative checks)
    conspiracy_keywords = ["complotto", "cospirazione", "microchip", "segreto", "agenda"]
    targeted_institutions = ["governo", "funzionari sanitari", "agenzie", "autorità"]
    negative_keywords = ["falso", "finta", "dannoso", "pericoloso", "infondato"]

    # Count occurrences
    conspiracy_count = sum(text.lower().count(kw) for kw in conspiracy_keywords)
    institutions_count = sum(text.lower().count(kw) for kw in targeted_institutions)
    negative_count = sum(text.lower().count(kw) for kw in negative_keywords)

    # Simple analysis logic
    if conspiracy_count > 0:
        analysis_report += f"- Il testo contiene {conspiracy_count} riferimenti a temi cospiratori.\n"
    if institutions_count > 0:
        analysis_report += f"- Il testo fa riferimento alle istituzioni {institutions_count} volte, potenzialmente indicando pregiudizi.\n"
    if negative_count > 0:
        analysis_report += f"- Il testo include terminologia negativa {negative_count} volte.\n"

    # Discussion of fairness
    # We can highlight that the entire text is unfairly representing real data and facts
    analysis_report += (
        "\nAnalisi complessiva dell'equità:\n"
        "Il rapporto ritrae i funzionari sanitari e i governi in una luce decisamente negativa e cospiratoria, "
        "attribuendo falsamente intenzioni maliziose (come il microchipping o la speculazione) senza prove. "
        "Nega inoltre l'efficacia del vaccino supportata scientificamente. Pertanto, il testo non è giusto o equilibrato. "
        "Diffonde paura, sfiducia e disinformazione infondate."
    )

    return analysis_report

bias_and_fairness_report = analyze_bias_and_fairness(extracted_text)
print("Analisi dei pregiudizi e dell'equità:")
print(bias_and_fairness_report)
# Out:
# Analisi dei pregiudizi e dell'equità:
# - Il testo contiene 3 riferimenti a temi cospiratori.
# - Il testo fa riferimento alle istituzioni 11 volte, potenzialmente indicando pregiudizi.
# - Il testo include terminologia negativa 3 volte.
#
# Analisi complessiva dell'equità:
# Il rapporto ritrae i funzionari sanitari e i governi in una luce decisamente negativa e cospiratoria, attribuendo falsamente intenzioni maliziose (come il microchipping o la speculazione) senza prove. Nega inoltre l'efficacia del vaccino supportata scientificamente. Pertanto, il testo non è giusto o equilibrato. Diffonde paura, sfiducia e disinformazione infondate.
